# %% [markdown]
# # <b>Linear Algebra for CpE

# %% [markdown]
# ### Laboratory 5: Multidimensional Vectors

# %% [markdown]
# <h5>Coded and Submitted by:
# <h5><i>Esguerra, Gian Karl J.<i>
# <h5><i>58011<i>

# %% [markdown]
# ### <b>TASK 1<b>

# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy.linalg import norm
# %matplotlib inline

# %% [markdown]
# $G = 4x + 7y - 2z$

# %%
G = np.array([4, 7, -2])

c = np.arange(0,50)
plt.xlim(0,10)
plt.ylim(0,10)

plt.plot(c*A[0], c*A[1], c*A[2], color='blue') 
plt.show()

# %% [markdown]
# ### <b>TASK 2<b>

# %% [markdown]
# $ K = \left\{ \begin{array}\\ 3x + 4y + 7z \\ 9x + 5y +2z \\ x + 2y + 7z\\\end{array} \right. $

# %%
K = np.array([
    [3,4,7],
    [9,5,2],
    [1,2,7]
])
fig = plt.figure()
ax1 = fig.gca(projection='3d')

ax1.set_xlim([0, 10])
ax1.set_ylim([0, 10])
ax1.set_zlim([0, 10])

origin = (0,0,0)
ax1.quiver(origin, origin, origin, A[:,0], A[:,1], A[:,2], 
           arrow_length_ratio=0.05, colors=['green','red','blue'])
plt.show()
